# %% [raw]
# # Data description - This dataset included hypothetical samples of 23 species of gilled mushrooms in the Agaricus and Lepiota family.
# # Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended.

# %%
#Importing requried libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Step 1. Data Selection

# %%
# Loading dataset
 
path ='https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv'
df = pd.read_csv(path)
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.head() #showing first five rows
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.sample() #showing middle five rows
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 7305     e         b           f         w       f    n               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 7305            w         b          w  ...                        k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 7305                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 7305           t         p                 w          n       g
#
# [1 rows x 23 columns]

# %%
df.tail() #showing last five rows
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
df.shape #checking shape
# Out:
# (8124, 23)

# %%
# There are 8124 rows and 23 columns in dataset.

# %%
df.info()  #information about dataset like data type, Null values etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.dtypes  #checking data types
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
#Every column has object (string) type data type.

# %%
df.isnull().sum()  #Checking the null values
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.duplicated().sum() #checking dublicates are not
# Out:
# 0

# %%
# This showing 8124 rows i.e., count of mushrooms and 23 columns that represent features like cap shape, cap surface etc.
#Class is the label/target value which include e - Edible and p - poisonous

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
# out of 8124 samples - 4208 are edible mushrooms and 3916 are poisonous mushrooms. Lets visualised by using bar graph.

# %%
data = df['class'].value_counts()

# %%
#visulzation
plt.figure(figsize = (10,5))
sns.barplot(data.index,data.values,alpha=0.6)
plt.xlabel('class',fontsize=14)
plt.ylabel('count',fontsize=14)
plt.title('Edible and poisonous mushrooms')
plt.show()

# %%
#visulization for all datasets
for columns in df.columns:
    plt.figure()
    sns.countplot(df[columns])
    sns.set(style='whitegrid')

# %%
df.columns #checking columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [raw]
# 2. Data Transformation

# %%
from sklearn.preprocessing import LabelEncoder #Importing requried libarary

# %%
le=LabelEncoder()
for column in df.columns:
    df[column]=le.fit_transform(df[column])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df.tail()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8119                         2                       5
# 8120                         2                       5
# ...

# %%
# So with the help of LabelEncoder, We convert Categorical data into numerical data. This data is easy to predict as cpmpare to categorical data.

# %%
df.describe() #statstical summary
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
# Count is 8124.There are some outliers in some columns like bruises,gill spacing, gill size etc. But this outliers are very minimal. So hardly affects dataset.

# %%
# Correlation

corr=df.corr()

# %%
corr
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=[25,20])
sns.heatmap(corr,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
df.drop('veil-type',axis=1,inplace=True)

# %%
df.drop('cap-surface',axis=1,inplace=True)

# %% [raw]
# Here, Veil-type have only one type so no impact on target variable and cap-surface having very less relation with class so we drop them

# %%
df.head()
# Out:
#    class  cap-shape  cap-color  bruises  odor  gill-attachment  gill-spacing  \
# 0      1          5          4        1     6                1             0
# 1      0          5          9        1     0                1             0
# 2      0          0          8        1     3                1             0
# 3      1          5          8        1     6                1             0
# 4      0          5          3        0     5                1             1
#
#    gill-size  gill-color  stalk-shape  ...  stalk-surface-above-ring  \
# 0          1           4            0  ...                         2
# 1          0           4            0  ...                         2
# 2          0           5            0  ...                         2
# 3          1           5            0  ...                         2
# 4          0           4            1  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %%
x=df.drop('class',axis=1)
x
# Out:
#       cap-shape  cap-color  bruises  odor  gill-attachment  gill-spacing  \
# 0             5          4        1     6                1             0
# 1             5          9        1     0                1             0
# 2             0          8        1     3                1             0
# 3             5          8        1     6                1             0
# 4             5          3        0     5                1             1
# ...         ...        ...      ...   ...              ...           ...
# 8119          3          4        0     5                0             0
# 8120          5          4        0     5                0             0
# 8121          2          4        0     5                0             0
# 8122          3          4        0     8                1             0
# 8123          5          4        0     5                0             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# ...

# %%
y=df['class']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %% [markdown]
# SMOTE

# %%
y.value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE  #required importing libraries

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
trainy.value_counts()
# Out:
# 1    4208
# 0    4208
# Name: class, dtype: int64

# %%
trainy
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8411    1
# 8412    1
# 8413    1
# 8414    1
# 8415    1
# Name: class, Length: 8416, dtype: int32

# %%
# Data Scaling
#StandardScaler = (X-mean)/std

from sklearn.preprocessing import StandardScaler # Importing requried library

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 1.02971224, -0.19824983,  1.18591657, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  1.76587407,  1.18591657, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  1.37304929,  1.18591657, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 , -0.19824983, -0.84322964, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152, -0.19824983, -0.84322964, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224, -0.19824983, -0.84322964, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
# Split data into train and test. Model will be built on training data and tested on test data.

from sklearn.model_selection import train_test_split  #Importing requied library

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=340)
y_train
# Out:
# 4899    0
# 6834    1
# 6596    1
# 4695    1
# 2094    0
#        ..
# 6689    1
# 247     0
# 5553    0
# 1058    0
# 644     0
# Name: class, Length: 6093, dtype: int32

# %% [raw]
# Step 6. Model training using ML algorithm

# %% [raw]
# LogisticRegression()  # we can use logistic regression

# %%
from sklearn.model_selection  import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predlr = LR.predict(x_test)

print(accuracy_score(y_test,predlr))

print(confusion_matrix(y_test,predlr))

print(classification_report(y_test,predlr))
# Out:
# 0.9571639586410635
# [[989  41]
#  [ 46 955]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1030
#            1       0.96      0.95      0.96      1001
#
#     accuracy                           0.96      2031
#    macro avg       0.96      0.96      0.96      2031
# weighted avg       0.96      0.96      0.96      2031

# %%
#Importing all Requried libraries
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier     
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
nb=MultinomialNB()

# %%
param={'kernel':['linear','rbf','poly','sigmoid']}
gd=GridSearchCV(svc,param,cv=5)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
param={'criterion':['ginny','entropy'],'splitter':['best','random'],'max_features':['none','auto','sqrt','log2']}
gd=GridSearchCV(dtc,param)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'criterion': 'entropy', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
param={'n_neighbors':[7,5,11],'weights':['uniform','distance'],'algorithm':['auto','bell_tree','kd_tree','brute']}
gd=GridSearchCV(knn,param)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}

# %%
svc=SVC(kernel='linear')
dtc=DecisionTreeClassifier(criterion='entropy',max_features='log2',splitter='random')
knn=KNeighborsClassifier(n_neighbors=5,weights='distance',algorithm='auto')
nb=MultinomialNB()

# %%
#From This GridSearchCV we will get best output as we taken

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Accuracy Score',accuracy_score(y_test,pred))
    print('Confusion Matrix\n',confusion_matrix(y_test,pred))
    print('Classification Report\n',classification_report(y_test,pred))
    print('F1 score',f1_score(y_test,pred))

# %%
fun(svc)
# Out:
# Accuracy Score 0.9753815854258986
# Confusion Matrix
#  [[1008   22]
#  [  28  973]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1030
#            1       0.98      0.97      0.97      1001
#
#     accuracy                           0.98      2031
#    macro avg       0.98      0.98      0.98      2031
# weighted avg       0.98      0.98      0.98      2031
#
# F1 score 0.9749498997995991

# %%
fun(dtc)
# Out:
# Accuracy Score 0.999015263417036
# Confusion Matrix
#  [[1030    0]
#  [   2  999]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1030
#            1       1.00      1.00      1.00      1001
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
#
# F1 score 0.999

# %%
fun(knn)
# Out:
# Accuracy Score 1.0
# Confusion Matrix
#  [[1030    0]
#  [   0 1001]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1030
#            1       1.00      1.00      1.00      1001
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
#
# F1 score 1.0

# %%
fun(LR)
# Out:
# Accuracy Score 0.9571639586410635
# Confusion Matrix
#  [[989  41]
#  [ 46 955]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1030
#            1       0.96      0.95      0.96      1001
#
#     accuracy                           0.96      2031
#    macro avg       0.96      0.96      0.96      2031
# weighted avg       0.96      0.96      0.96      2031
#
# F1 score 0.9564346519779671

# %% [raw]
# Cross Validation

# %%
#importing Libraries
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
score=cross_val_score(SVC(kernel='linear'),x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.78584615 0.98523077 0.88       0.99815385 0.70935961]
# 0.8717180750284198

# %%
score=cross_val_score(DecisionTreeClassifier(criterion='entropy',max_features='log2',splitter='random'),x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.84246154 1.         1.         1.         0.80788177]
# 0.9300686623721107

# %%
score=cross_val_score(KNeighborsClassifier(n_neighbors=5,weights='distance',algorithm='auto'),x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.85107692 1.         0.944      1.         0.65640394]
# 0.8902961727927245

# %%
score=cross_val_score(MultinomialNB(),x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.58830769 0.64246154 0.71507692 0.99753846 0.68226601]
# 0.7251301250473664

# %% [raw]
# Ensemble Method

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier  #importing libray.

# %%
rfc=RandomForestClassifier(n_estimators=100,random_state=23)
ad=AdaBoostClassifier()
Gbd=GradientBoostingClassifier(n_estimators=200,learning_rate=0.1)

# %%
fun(rfc)
# Out:
# Accuracy Score 1.0
# Confusion Matrix
#  [[1030    0]
#  [   0 1001]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1030
#            1       1.00      1.00      1.00      1001
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
#
# F1 score 1.0

# %%
fun(ad)
# Out:
# Accuracy Score 1.0
# Confusion Matrix
#  [[1030    0]
#  [   0 1001]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1030
#            1       1.00      1.00      1.00      1001
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
#
# F1 score 1.0

# %%
fun(Gbd)
# Out:
# Accuracy Score 1.0
# Confusion Matrix
#  [[1030    0]
#  [   0 1001]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1030
#            1       1.00      1.00      1.00      1001
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
#
# F1 score 1.0

# %% [raw]
# Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier  #import library

# %%
estimator=[]

estimator.append(('svc',SVC(kernel='linear')))
estimator.append(('dtc',DecisionTreeClassifier(criterion='entropy',max_features='log2',splitter='random')))
estimator.append(('knn',KNeighborsClassifier(n_neighbors=5,weights='distance',algorithm='auto')))
estimator.append(('nb',MultinomialNB()))

# %%
vot_soft=VotingClassifier(estimators=estimator,voting='soft')
vot_soft.fit(x_train,y_train)
y_pred=vot_soft.predict(x_test)
print(y_pred)
#usint accuracy score
score=(accuracy_score(y_test,y_pred))
print('soft voting score % d'% score)

# %% [raw]
# AUC ROC CURVE

# %%
from sklearn.metrics import roc_curve  #importing library

# %%
y_pred_prob=rfc.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([1., 1., 0., ..., 0., 1., 1.])

# %%
fpr,tpr,thersholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.00291262, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.98801199, 0.995005  , 0.999001  , 1.        ,
#        1.        , 1.        ])

# %%
thersholds
# Out:
# array([2.  , 1.  , 0.99, 0.97, 0.96, 0.01, 0.  ])

# %%
#visulization of AUC RUC 
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression')
plt.show()

# %% [raw]
# For applying Different model we can see that our model is in underfitting and overfilling so we apply cross validation and ensemble method to improve the result or boosting the model nd from that we get best result in RandomForest and AdaboosClassifier

# %% [raw]
# 8 .Saving Model

# %%
import pickle
filename='Mashroom_Prediction.pkl'
pickle.dump(rfc,open(filename,'wb'))

# %% [markdown]
# Conclusion :

# %%
result =pd.DataFrame()
result['Actual']=y_test
result['Predict']=rfc.predict(x_test)

print(result)
sns.catplot(data=result)
# Out:
#       Actual  Predict
# 4498       1        1
# 5360       1        1
# 4276       0        0
# 7048       1        1
# 5544       0        0
# ...      ...      ...
# 4516       1        1
# 4356       1        1
# 2705       0        0
# 6001       1        1
# 4371       1        1
#
# [2031 rows x 2 columns]
