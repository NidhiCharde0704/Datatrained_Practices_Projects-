# %% [markdown]
# Data Description
#
# #The World Happiness Report is a landmark survey of state of global happiness. It describe how measurements of wel-being can be used effectively to assess the progress of nation. The happiness score and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in poll. This questions known as the Cantril ladder with best possible score is 10 and worst is 0.
#
# World Happines report consists of six columns like Economic production, Social support, Life expectancy, Freedom, Absence of corruption and Generosity. It also consist of hypothetical country named Dystopia that has values equal to the world's lowest national averages for each of the six factors.

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the data
df = pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.head() #showing first five rows
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.tail() #showing last five rows
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %%
df.info() #information about dataset like data type, Null values etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [raw]
# EDA (Visulization)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# NO Null data present in this dataset

# %%
#visualization for null values

plt.figure(figsize=[20,9])
sns.heatmap(df.isnull())
plt.title('null values')
plt.show()

# %%
df.shape # Checking shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Visulization using univeriant
plt.figure(figsize=(20,8))
sns.countplot(df['Region'])
plt.title('Count of Region')
plt.tight_layout()

# %%
#This Chart we can seethat Sub Saharan Africa Region Having highest country and North America having lowest Countries.

# %%
#visulization using violinplot to calculate happiness score
sns.violinplot(x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %%
#Most of the country having score is in range 4-7

# %%
#visulization using violinplot to calculate dystopia Residual 
sns.violinplot(x='Dystopia Residual',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
#Dystopia Residual having range between 1.5 to 3.0

# %%
column=['Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
plt.figure(figsize=(8,10))
for i in range(len(column)):
    sns.distplot(df[column[i]])
    plt.subplot(5,2,i+1)
    plt.tight_layout()
    plt.title('Distribution Chart ')

# %%
 # Visulization using Bivariate Analysis
    
plt.figure(figsize=(8,10))
for i in range(len(column)):
    sns.scatterplot(df[column[i]],'Happiness Score',data=df)
    plt.subplot(5,2,i+1)
    plt.tight_layout()

# %%
#This chart shows as the Economy(GDP per Capita)increaases happiness score Increases

# %%
sns.scatterplot(y='Happiness Rank',x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Happiness Rank'>

# %%
sns.scatterplot(y='Economy (GDP per Capita)',x='Family',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Economy (GDP per Capita)'>

# %%
#we cas see the as the Family Increases Economy(GDP per Capita)also increases

# %%
#visulization using swarmplot
plt.figure(figsize=(20,5))
sns.swarmplot(x='Region',y='Happiness Score',data=df)
plt.tight_layout()
plt.title('Happiness Score Vs Region')
# Out:
# Text(0.5, 1.0, 'Happiness Score Vs Region')

# %%
#This Chart Show that Africa Sub saharan Africa has lowest Happiness Score and Western Europe having High Happiness Score

# %%
#visulization using striplot
plt.figure(figsize=(20,5))
sns.stripplot(x='Region',y='Economy (GDP per Capita)',data=df)
plt.tight_layout()
plt.title('Economy (GDP per Capita) Vs Region')
# Out:
# Text(0.5, 1.0, 'Economy (GDP per Capita) Vs Region')

# %%
#From this chart we can see that Economy(GDP per capita) is lower in Sub saharan Africa and higher in Middle East and Northen Africa.as well as in western europe

# %%
#visulization using strip plot to caluclate Region and Dystopia
plt.figure(figsize=(20,5))
sns.stripplot(x='Region',y='Dystopia Residual',data=df)
plt.tight_layout()
plt.title('Dystopia Residual Vs Region')
# Out:
# Text(0.5, 1.0, 'Dystopia Residual Vs Region')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])
df['Region']=le.fit_transform(df['Region'])

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %% [raw]
# Stastices

# %%
df.describe() #statstices summery
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
#find correlation

corr = df.corr()

# %%
#visualization for coorelated values
plt.figure(figsize=(15,15))
sns.heatmap(data=corr,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
#we can see that some features having skewness

# %%
#This Relation show that Standard Error having negative relation with Happiness Score

# %% [raw]
#  Data Cleaning

# %%
#Checking Outliers
for i in range(len(column)):
    sns.boxplot(df[column[i]])
    plt.title('i')
    plt.subplot(5,2,i+1)
    plt.show

# %%
#This Chart shows Outliers are present in Some Features

# %%
from scipy.stats import zscore #import libraries

# %%
z=abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 12 columns]

# %%
print(df.shape) #checking shape
print(df_new.shape) #checking upadte new shape values
# Out:
# (158, 12)
# (149, 12)

# %%
pre_loss=(158-149)/158*100
pre_loss
# Out:
# 5.69620253164557

# %%
df_new.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
sd=pd.DataFrame([['Standard Error','1.24','Negative Relation with Target','More']],columns=['Name','Skewness','Corelation','Outliers'])
sd
# Out:
#              Name Skewness                     Corelation Outliers
# 0  Standard Error     1.24  Negative Relation with Target     More

# %%
#Standard Error having high skewness as well as negagtive relation with score so we will drop it

# %%
df_new.drop('Standard Error',axis=1,inplace=True)

# %%
df_new.drop('Happiness Rank',axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    Country  Region  Happiness Score  Economy (GDP per Capita)   Family  \
# 0      135       9            7.587                   1.39651  1.34951
# 1       58       9            7.561                   1.30232  1.40223
# 2       37       9            7.527                   1.32548  1.36058
# 3      105       9            7.522                   1.45900  1.33095
# 4       24       5            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
y=df_new['Happiness Score']
y.shape
# Out:
# (149,)

# %%
x=df_new.drop('Happiness Score',axis=1)
x.shape
# Out:
# (149, 9)

# %% [raw]
# Removing Skewness

# %%
from sklearn.preprocessing import power_transform #importing libraries

# %%
x_new=power_transform(x,method='yeo-johnson')

# %%
x_new
# Out:
# array([[ 1.19015533,  1.23451354,  1.49245411, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [-0.30048669,  1.23451354,  1.19406711, ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354,  1.26661161, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577, -1.36521585, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966, -1.93874732, ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %% [raw]
# Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Data Scaling
#StandardScaler = (X-mean)/std

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_new)
x_scaled
# Out:
# array([[ 1.19015533,  1.23451354,  1.49245411, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [-0.30048669,  1.23451354,  1.19406711, ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354,  1.26661161, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577, -1.36521585, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966, -1.93874732, ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
x_scaled
# Out:
# array([[ 1.19015533,  1.23451354,  1.49245411, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [-0.30048669,  1.23451354,  1.19406711, ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354,  1.26661161, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577, -1.36521585, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966, -1.93874732, ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
x= x_scaled

# %% [raw]
# Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score

# %%
# Split data into train and test. Model will be built on training data and tested on test data

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=340)
y_train
# Out:
# 94     4.959
# 102    4.839
# 123    4.436
# 127    4.332
# 150    3.655
#        ...
# 2      7.527
# 133    4.218
# 34     6.411
# 35     6.329
# 137    3.995
# Name: Happiness Score, Length: 111, dtype: float64

# %%
# Model instantiating and training

regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# To find Intercept
print(regression.intercept_)

# To find coefficients
print(regression.coef_)
# Out:
# 5.426454220377532
# [ 0.01795093 -0.04355012  0.38897397  0.24693815  0.24780526  0.1497143
#   0.08984059  0.11218201  0.51100404]

# %%
# Adjusted R2 Score 

regression.score(x_train,y_train)
# Out:
# 0.9957605912092065

# %%
regression.score(x_test,y_test)
# Out:
# 0.9938917803859625

# %%
y_pred = regression.predict(x_test)
y_pred
# Out:
# array([4.76287034, 4.53378842, 4.1859907 , 5.81316167, 5.76071345,
#        6.1809259 , 4.30024045, 5.4726741 , 6.11029899, 4.14485279,
#        6.43517411, 7.63437944, 5.12117278, 6.66416726, 3.79331833,
#        3.91413878, 4.8875235 , 5.67866953, 4.813293  , 5.3139504 ,
#        5.16179871, 5.81577586, 6.08251757, 5.12442547, 4.95686277,
#        6.8986948 , 5.70268959, 5.64470772, 5.06356334, 6.96662804,
#        3.7313193 , 7.24177949, 7.44202692, 3.85139716, 5.11977692,
#        5.48660522, 4.51374892, 7.21805715])

# %%
data = pd.DataFrame({'Acutal data':y_test,'Predicted data':y_pred})
data
# Out:
#      Acutal data  Predicted data
# 98         4.876        4.762870
# 113        4.633        4.533788
# 132        4.252        4.185991
# 58         5.813        5.813162
# 57         5.824        5.760713
# 45         5.987        6.180926
# 126        4.350        4.300240
# 67         5.605        5.472674
# 46         5.984        6.110299
# 134        4.194        4.144853
# 32         6.477        6.435174
# 0          7.587        7.634379
# 86         5.123        5.121173
# 26         6.670        6.664167
# 142        3.896        3.793318
# 139        3.956        3.914139
# 99         4.874        4.887523
# 63         5.716        5.678670
# 105        4.786        4.813293
# 75         5.332        5.313950
# 73         5.399        5.161799
# 56         5.828        5.815776
# 44         5.995        6.082518
# 88         5.098        5.124425
# 91         5.013        4.956863
# 19         6.901        6.898695
# 61         5.759        5.702690
# 66         5.689        5.644708
# 87         5.102        5.063563
# 18         6.937        6.966628
# 152        3.575        3.731319
# 12         7.200        7.241779
# 4          7.427        7.442027
# 141        3.904        3.851397
# 81         5.192        5.119777
# 72         5.429        5.486605
# 121        4.512        4.513749
# 14         7.119        7.218057

# %%
#Visulization
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.title('Actual Data Vs Predicted Data')
plt.show()

# %%
print('Mean absolute error :',mean_absolute_error(y_test,y_pred))
print('Mean squared error :',mean_squared_error(y_test,y_pred))
print('Root mean squared error :', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean absolute error : 0.060992164986632
# Mean squared error : 0.006549439768261885
# Root mean squared error : 0.08092860908394438

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
dtc=DecisionTreeRegressor()
kn=KNeighborsRegressor(n_neighbors=5)
svm=SVR()
svmp=SVR(kernel='poly')
svml=SVR(kernel='linear')

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Taining Score:-',f.score(x_train,y_train)*100)
    print('Mean Absolute Error',mean_absolute_error(y_test,pred))
    print('Mean Squared Error',mean_squared_error(y_test,pred))
    print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,pred)))

# %%
fun(dtc)
# Out:
# Taining Score:- 100.0
# Mean Absolute Error 0.39778947368421064
# Mean Squared Error 0.2290392631578948
# Root Mean Squared Erro 0.4785804667533923

# %%
fun(kn)
# Out:
# Taining Score:- 92.63357270827495
# Mean Absolute Error 0.2312842105263157
# Mean Squared Error 0.09421034105263161
# Root Mean Squared Erro 0.30693703108721115

# %%
fun(svm)
# Out:
# Taining Score:- 98.91612593866296
# Mean Absolute Error 0.12238042334736594
# Mean Squared Error 0.02661115126948559
# Root Mean Squared Erro 0.16312924713087346

# %%
fun(svmp)
# Out:
# Taining Score:- 96.29683292382923
# Mean Absolute Error 0.2543072668465725
# Mean Squared Error 0.0969760955068388
# Root Mean Squared Erro 0.311409851332354

# %%
fun(svml)
# Out:
# Taining Score:- 99.54618356389913
# Mean Absolute Error 0.06857769746183734
# Mean Squared Error 0.0069158555721895035
# Root Mean Squared Erro 0.08316162319357111

# %% [raw]
# Regurisation

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet #importing libraries

# %%
ls=Lasso(alpha=0.0001,normalize=False)
rd=Ridge(alpha=0.0001,normalize=False)
es=ElasticNet(alpha=0.0001)

# %%
fun(ls)
# Out:
# Taining Score:- 99.57605485313263
# Mean Absolute Error 0.06090676480285623
# Mean Squared Error 0.006533900212840738
# Root Mean Squared Erro 0.08083254426801582

# %%
fun(rd)
# Out:
# Taining Score:- 99.5760591208909
# Mean Absolute Error 0.060992084570971425
# Mean Squared Error 0.006549431343830934
# Root Mean Squared Erro 0.08092855703539346

# %%
fun(es)
# Out:
# Taining Score:- 99.5760576656515
# Mean Absolute Error 0.0609459986122761
# Mean Squared Error 0.006540737300746208
# Root Mean Squared Erro 0.08087482488850413

# %% [markdown]
# From the Diffenet models DTC having good Score.

# %% [raw]
# Saving Model

# %%
import pickle
filename='Happines_Score_Prediction.pkl'
pickle.dump(dtc,open(filename,'wb'))

# %% [raw]
# Conclusion

# %%
es=pd.DataFrame()
data['Actual']=y_test
data['Predict']=y_pred

print(data)
sns.lineplot(data=data)
# Out:
#      Acutal data  Predicted data  Actual   Predict
# 98         4.876        4.762870   4.876  4.762870
# 113        4.633        4.533788   4.633  4.533788
# 132        4.252        4.185991   4.252  4.185991
# 58         5.813        5.813162   5.813  5.813162
# 57         5.824        5.760713   5.824  5.760713
# 45         5.987        6.180926   5.987  6.180926
# 126        4.350        4.300240   4.350  4.300240
# 67         5.605        5.472674   5.605  5.472674
# 46         5.984        6.110299   5.984  6.110299
# 134        4.194        4.144853   4.194  4.144853
# 32         6.477        6.435174   6.477  6.435174
# 0          7.587        7.634379   7.587  7.634379
# 86         5.123        5.121173   5.123  5.121173
# 26         6.670        6.664167   6.670  6.664167
# 142        3.896        3.793318   3.896  3.793318
# 139        3.956        3.914139   3.956  3.914139
# 99         4.874        4.887523   4.874  4.887523
# 63         5.716        5.678670   5.716  5.678670
# 105        4.786        4.813293   4.786  4.813293
# 75         5.332        5.313950   5.332  5.313950
# 73         5.399        5.161799   5.399  5.161799
# 56         5.828        5.815776   5.828  5.815776
# 44         5.995        6.082518   5.995  6.082518
# 88         5.098        5.124425   5.098  5.124425
# 91         5.013        4.956863   5.013  4.956863
# 19         6.901        6.898695   6.901  6.898695
# 61         5.759        5.702690   5.759  5.702690
# 66         5.689        5.644708   5.689  5.644708
# 87         5.102        5.063563   5.102  5.063563
# 18         6.937        6.966628   6.937  6.966628
# 152        3.575        3.731319   3.575  3.731319
# 12         7.200        7.241779   7.200  7.241779
# 4          7.427        7.442027   7.427  7.442027
# 141        3.904        3.851397   3.904  3.851397
# 81         5.192        5.119777   5.192  5.119777
# 72         5.429        5.486605   5.429  5.486605
# 121        4.512        4.513749   4.512  4.513749
# 14         7.119        7.218057   7.119  7.218057
# <AxesSubplot:>
